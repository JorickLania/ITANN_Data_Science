# %% [markdown]
# # First Notebook File
# Hier gaan we wat dingen doen.

# %%
printable = 'Good Afternoon!'
print(f"Voice of the Machine says: {printable}")
# Out:
# Voice of the Machine says: Good Afternoon!
